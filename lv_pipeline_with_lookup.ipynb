# %%
import cupy

print(cupy.show_config())
# Out:
# OS                           : Linux-6.14.0-29-generic-x86_64-with-glibc2.39
# Python Version               : 3.12.3
# CuPy Version                 : 13.6.0
# CuPy Platform                : NVIDIA CUDA
# NumPy Version                : 2.3.2
# SciPy Version                : None
# Cython Build Version         : 3.0.12
# Cython Runtime Version       : None
# CUDA Root                    : /usr/local/cuda-12.8
# nvcc PATH                    : /usr/local/cuda-12.8/bin/nvcc
# CUDA Build Version           : 12090
# CUDA Driver Version          : 12080
# CUDA Runtime Version         : 12090 (linked to CuPy) / 12080 (locally installed)
# CUDA Extra Include Dirs      : ['/home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages/nvidia/cuda_runtime/include']
# cuBLAS Version               : (available)
# cuFFT Version                : 11303
# cuRAND Version               : 10309
# cuSOLVER Version             : (11, 7, 3)
# cuSPARSE Version             : (available)
# NVRTC Version                : (12, 8)
# Thrust Version               : 200800
# CUB Build Version            : 200800
# Jitify Build Version         : <unknown>
# cuDNN Build Version          : (not loaded; try `import cupy.cuda.cudnn` first)
# cuDNN Version                : (not loaded; try `import cupy.cuda.cudnn` first)
# NCCL Build Version           : (not loaded; try `import cupy.cuda.nccl` first)
# NCCL Runtime Version         : (not loaded; try `import cupy.cuda.nccl` first)
# cuTENSOR Version             : None
# cuSPARSELt Build Version     : None
# Device 0 Name                : NVIDIA GeForce RTX 5080
# Device 0 Compute Capability  : 120
# Device 0 PCI Bus ID          : 0000:01:00.0
# None

# %%
# Cell 1: 
import spacy 
from pathlib import Path 
import os 
# 查看 spaCy 版本和可用组件 
spacy.info()
# Out:
# {'spacy_version': '3.8.7',
#  'location': '/home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages/spacy',
#  'platform': 'Linux-6.14.0-29-generic-x86_64-with-glibc2.39',
#  'python_version': '3.12.3',
#  'pipelines': {}}

# %%
# Cell 2:
# 创建 corpus 和 models 文件夹
Path("./corpus").mkdir(parents=True, exist_ok=True)
Path("./models").mkdir(parents=True, exist_ok=True)

# %%
# Cell 3:
# !python -m spacy convert ud_latvian/lv_lvtb-ud-train.conllu ./corpus
# !python -m spacy convert ud_latvian/lv_lvtb-ud-dev.conllu ./corpus
# !python -m spacy convert ud_latvian/lv_lvtb-ud-test.conllu ./corpus
# Out:
# ℹ Grouping every 1 sentences into a document.
# ⚠ To generate better training data, you may want to group sentences
# into documents with `-n 10`.
# ✔ Generated output file (15055 documents):
# corpus/lv_lvtb-ud-train.spacy
# ℹ Grouping every 1 sentences into a document.
# ⚠ To generate better training data, you may want to group sentences
# into documents with `-n 10`.
# ✔ Generated output file (2080 documents):
# corpus/lv_lvtb-ud-dev.spacy
# ℹ Grouping every 1 sentences into a document.
# ⚠ To generate better training data, you may want to group sentences
# into documents with `-n 10`.
# ✔ Generated output file (2396 documents):
# corpus/lv_lvtb-ud-test.spacy

# %%
#Cell 4: 
# !python -m spacy init config config.cfg --lang lv --pipeline tok2vec,tagger,morphologizer,parser --optimize efficiency
# Out:
# ℹ Generated config template specific for your use case
# - Language: lv
# - Pipeline: tagger, morphologizer, parser
# - Optimize for: efficiency
# - Hardware: CPU
# - Transformer: None
# ✔ Auto-filled config with all values
# ✔ Saved config
# config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
# Cell 5: 
cfg_text = Path("config.cfg").read_text(encoding="utf-8")
cfg_text = cfg_text.replace("train = null", "train = ./corpus/lv_lvtb-ud-train.spacy")
cfg_text = cfg_text.replace("dev = null", "dev = ./corpus/lv_lvtb-ud-dev.spacy")
Path("config.cfg").write_text(cfg_text, encoding="utf-8")
print("✅ 已经修改 config.cfg 的数据路径")
# Out:
# ✅ 已经修改 config.cfg 的数据路径

# %%
# Cell 6: 使用 GPU 训练 
# !python -m spacy train config.cfg --output ./models --paths.train ./corpus/lv_lvtb-ud-train.spacy --paths.dev ./corpus/lv_lvtb-ud-dev.spacy --gpu-id 0
# Out:
# ℹ Saving to output directory: models
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'tagger', 'morphologizer', 'parser']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS TAGGER  LOSS MORPH...  LOSS PARSER  TAG_ACC  POS_ACC  MORPH_ACC  DEP_UAS  DEP_LAS  SENTS_F  SCORE
# ---  ------  ------------  -----------  -------------  -----------  -------  -------  ---------  -------  -------  -------  ------
#   0       0          0.00        87.49          87.46       278.06    14.64    25.48      15.06     7.89     6.41     0.08    0.14
#   0     200       2720.41     13465.03       12743.87     24709.62    46.00    74.19      51.85    47.61    29.28    80.65    0.50
#   0     400       5448.86     12816.42       11640.31     23172.35    60.89    83.48      68.28    59.32    43.56    41.29    0.63
#   0     600       7603.59     12742.24       10986.01     25559.40    68.95    87.58      76.15    63.37    50.16    78.52    0.70
#   0     800       9426.85     13297.07       10918.24     27850.94    73.31    89.72      80.23    67.37    55.77    94.69    0.74
#   0    1000      11740.17     14579.30       11792.54     31174.46    76.71    91.20      83.01    70.96    61.17    96.93    0.77
#   0    1200      14739.25     16078.50       12960.07     35977.89    78.95    92.37      85.17    72.41    63.76    98.73    0.79
#   1    1400      17575.45     17384.56       13773.28     40332.95    80.44    93.06      85.98    73.91    65.93    97.88    0.81
#   1    1600      21707.02     18796.72       14647.10     44889.64    81.71    93.24      87.21    75.68    68.32    98.56    0.82
#   1    1800      27047.47     21951.65       17073.41     52787.52    83.08    93.79      88.19    76.96    69.99    99.04    0.83
#   2    2000      32505.45     23537.77       18039.95     57720.00    84.06    94.11      88.78    77.82    71.03    99.64    0.84
#   2    2200      40659.33     27326.97       20775.47     66578.77    84.74    94.35      89.22    78.00    71.80    99.64    0.85
#   3    2400      47941.39     28207.47       20996.32     71751.39    85.52    94.46      89.75    78.68    72.90    99.50    0.85
#   4    2600      49538.60     27075.69       20052.96     69042.88    85.45    94.65      89.77    79.08    73.29    99.57    0.85
#   5    2800      50692.07     25517.92       18820.29     65581.11    86.01    94.78      90.10    79.83    73.92    99.62    0.86
#   6    3000      52990.16     24408.96       17844.91     63672.37    86.22    94.83      90.27    80.10    74.32    99.86    0.86
#   6    3200      52580.98     22404.52       16252.71     58881.65    86.44    94.92      90.57    80.32    74.72    99.78    0.86
#   7    3400      53934.89     21101.45       15289.54     56470.89    86.54    95.03      90.63    80.46    74.92    99.86    0.87
#   8    3600      55188.67     20652.84       14967.54     54522.13    86.69    95.09      90.67    80.51    74.91    99.78    0.87
#   9    3800      57079.73     19930.25       14397.76     53195.77    86.76    95.13      90.71    80.91    75.39    99.86    0.87
#   9    4000      58405.16     18851.58       13454.24     50305.71    86.88    95.13      90.88    81.17    75.77    99.71    0.87
#  10    4200      57740.80     18042.69       12849.76     47493.31    86.87    95.08      90.81    81.06    75.46   100.00    0.87
#  11    4400      59345.60     17453.59       12462.20     47316.23    87.04    95.10      90.80    81.22    75.79    99.78    0.87
#  12    4600      61554.94     17161.06       12204.44     46165.70    86.74    95.19      90.68    81.13    75.64    99.86    0.87
#  12    4800      63129.68     16548.38       11676.37     44292.37    87.12    95.24      90.92    81.54    76.05    99.78    0.87
#  13    5000      62576.88     15648.66       11086.71     41871.05    86.99    95.27      90.88    81.27    76.03    99.64    0.87
#  14    5200      64539.57     15480.86       10994.41     41241.26    87.10    95.26      90.88    81.36    76.02    99.86    0.87
#  15    5400      67266.09     15392.11       10902.54     40536.62    87.27    95.35      91.01    81.33    75.98    99.71    0.87
#  15    5600      69369.51     14926.72       10500.59     40089.49    87.25    95.27      91.01    81.27    75.97    99.78    0.87
#  16    5800      67268.33     14022.99        9801.55     37272.45    87.11    95.21      90.84    81.34    75.83    99.78    0.87
#  17    6000      70064.95     14025.23        9828.33     37585.46    87.20    95.12      90.99    81.24    75.79    99.71    0.87
#  18    6200      72613.78     14049.41        9906.89     37510.68    87.26    95.27      91.01    81.35    76.03    99.71    0.87
#  18    6400      75745.85     13996.37        9815.35     37038.99    87.44    95.42      90.93    81.45    76.03    99.78    0.87
#  19    6600      72085.68     13066.93        9141.49     33873.27    87.40    95.34      90.99    81.27    76.03    99.78    0.87
#  20    6800      75664.24     12985.02        9044.52     34194.05    87.37    95.26      90.96    81.55    76.09    99.86    0.87
#  21    7000      75705.68     12784.08        8918.06     32935.54    87.46    95.43      90.94    81.64    76.20    99.93    0.87
#  22    7200      79369.72     12669.52        8848.16     33266.64    87.23    95.35      91.07    81.47    76.21    99.86    0.87
#  22    7400      77896.62     12206.93        8552.24     31182.13    87.39    95.46      91.09    81.65    76.23    99.93    0.87
#  23    7600      79999.74     12095.22        8413.15     31185.83    87.40    95.35      91.09    81.47    75.99    99.50    0.87
#  24    7800      81616.65     11965.86        8312.13     31286.44    87.34    95.27      91.15    81.37    76.02    99.71    0.87
#  25    8000      84223.75     11961.80        8342.28     30782.44    87.42    95.41      91.10    81.53    76.08    99.86    0.87
#  25    8200      85534.17     11639.14        8077.96     29764.42    87.31    95.32      91.08    81.42    76.12    99.71    0.87
#  26    8400      86174.49     11494.49        7999.89     28930.47    87.49    95.22      91.06    81.33    75.99    99.71    0.87
#  27    8600      87136.72     11340.15        7820.85     28550.95    87.41    95.32      91.12    81.50    76.20    99.78    0.87
#  28    8800      91593.87     11366.65        7917.63     29037.97    87.60    95.45      91.16    81.77    76.36    99.78    0.88
#  28    9000      91434.86     11288.63        7765.19     27877.10    87.57    95.41      91.27    81.29    76.09    99.71    0.87
#  29    9200      90534.71     10867.63        7543.88     26498.70    87.47    95.36      91.25    81.45    76.28    99.64    0.87
#  30    9400      91691.11     10874.41        7578.30     26805.93    87.38    95.34      91.20    81.22    76.05    99.78    0.87
#  31    9600      95173.04     10870.18        7538.03     26720.32    87.56    95.31      91.18    81.26    76.01    99.78    0.87
#  31    9800      96805.23     10847.08        7477.58     26602.37    87.53    95.36      91.25    81.32    75.93    99.86    0.87
#  32   10000      92189.24     10031.19        6983.37     24198.96    87.53    95.33      91.17    81.59    76.21    99.86    0.87
#  33   10200      98154.28     10324.93        7122.99     25177.79    87.55    95.37      91.09    81.42    76.23    99.71    0.87
#  34   10400     101368.92     10218.66        7104.68     25283.48    87.52    95.38      91.22    81.73    76.47    99.78    0.87
# ✔ Saved pipeline to output directory
# models/model-last

# %%
# Cell 6.5: 手动把 lookup.json 挂进模型
import shutil
from pathlib import Path

# 确保目录存在
Path("models/model-best/lookups").mkdir(parents=True, exist_ok=True)
Path("models/model-last/lookups").mkdir(parents=True, exist_ok=True)

# 拷贝 lookup.json 到两个模型里
shutil.copy("lookup.json", "models/model-best/lookups/lemma_lookup.json")
shutil.copy("lookup.json", "models/model-last/lookups/lemma_lookup.json")

print("✅ 已经把 lookup.json 挂到 model-best 和 model-last")
# Out:
# ✅ 已经把 lookup.json 挂到 model-best 和 model-last

# %%
# Cell 7: 
# !python -m spacy evaluate ./models/model-best ./corpus/lv_lvtb-ud-test.spacy
# Out:
# ℹ Using CPU
# ℹ To switch to GPU 0, use the option: --gpu-id 0
#
# ================================== Results ==================================
#
# TOK      99.53
# TAG      86.95
# POS      94.85
# MORPH    90.84
# UAS      81.23
# LAS      75.64
# SENT P   100.00
# SENT R   100.00
# SENT F   100.00
# SPEED    14303
#
#
# ============================== MORPH (per feat) ==============================
#
#                P       R       F
# ExtPos     90.91   86.33   88.56
# Case       92.22   91.58   91.90
# Gender     93.73   92.99   93.36
# Number     94.09   92.90   93.49
# Person     95.30   93.98   94.63
# PronType   98.42   97.86   98.14
# Evident    94.35   93.03   93.69
# Mood       93.73   92.05   92.88
# Polarity   94.09   92.59   93.33
# Tense      91.23   89.06   90.13
# VerbForm   92.75   91.25   91.99
# Voice      93.83   91.34   92.57
# Definite   90.44   87.94   89.17
# Degree     92.67   90.84   91.75
# Poss       97.85   99.45   98.64
# NumType    98.85   77.06   86.60
# Reflex     93.39   92.69   93.04
# Aspect     89.07   85.09   87.03
# Foreign    79.85   56.32   66.05
# Typo        0.00    0.00    0.00
# Abbr       96.22   81.28   88.12
#
#
# =============================== LAS (per type) ===============================
#
#                     P       R       F
# mark            85.77   86.68   86.22
# fixed           84.87   92.81   88.66
# nsubj           80.71   81.04   80.87
# discourse       69.79   58.09   63.40
# advcl           61.46   55.27   58.20
# amod            82.20   78.38   80.25
# obj             79.38   80.61   79.99
# cc              82.45   82.35   82.40
# det             85.63   83.28   84.44
# conj            57.53   61.83   59.60
# xcomp           76.03   73.85   74.93
# aux             92.49   92.86   92.67
# root            84.79   84.47   84.63
# nmod            77.92   78.04   77.98
# ccomp           71.22   70.75   70.98
# nummod          83.15   81.69   82.42
# case            91.50   90.87   91.18
# iobj            58.82   56.93   57.86
# advmod          78.72   81.52   80.09
# obl             68.85   64.05   66.36
# acl             64.56   67.11   65.81
# advmod:emph     67.64   67.15   67.39
# advmod:neg      53.57   60.00   56.60
# csubj           67.11   50.00   57.30
# cop             71.57   77.89   74.60
# aux:pass        89.25   89.25   89.25
# nsubj:pass      76.16   84.25   80.00
# parataxis       54.74   46.85   50.49
# appos           35.19   28.36   31.40
# dep              1.47    1.08    1.24
# csubj:pass      42.86   25.00   31.58
# flat            65.52   46.34   54.29
# flat:foreign   100.00    8.33   15.38
# flat:name       83.82   71.55   77.20
# vocative        22.22    6.90   10.53
# orphan          34.29   12.00   17.78
# reparandum       0.00    0.00    0.00
# compound       100.00   33.33   50.00
# goeswith         0.00    0.00    0.00
# dislocated       0.00    0.00    0.00

# %%
# Cell 8: 打包模型
from pathlib import Path

# 确保 packages 文件夹存在
Path("./packages").mkdir(parents=True, exist_ok=True)

# 打包模型，注意包名不要和路径重复
# !python -m spacy package ./models/model-best ./packages --name latvian_model --version 1.0.0 --force
# Out:
# /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages/click/core.py:1193: UserWarning: The parameter -R is used more than once. Remove its duplicate as parameters should be unique.
#   parser = self.make_parser(ctx)
# /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages/click/core.py:1186: UserWarning: The parameter -R is used more than once. Remove its duplicate as parameters should be unique.
#   self.parse_args(ctx, args)
# ℹ Building package artifacts: sdist
# ✔ Including 1 package requirement(s) from meta and config
# spacy>=3.8.7,<3.9.0
# ✔ Loaded meta.json from file
# models/model-best/meta.json
# ✔ Generated README.md from meta.json
# ✔ Successfully created package directory 'lv_latvian_model-1.0.0'
# packages/lv_latvian_model-1.0.0
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - setuptools >= 40.8.0
# * Getting build dependencies for sdist...
# running egg_info
# creating lv_latvian_model.egg-info
# writing lv_latvian_model.egg-info/PKG-INFO
# writing dependency_links to lv_latvian_model.egg-info/dependency_links.txt
# writing entry points to lv_latvian_model.egg-info/entry_points.txt
# writing requirements to lv_latvian_model.egg-info/requires.txt
# writing top-level names to lv_latvian_model.egg-info/top_level.txt
# writing manifest file 'lv_latvian_model.egg-info/SOURCES.txt'
# reading manifest file 'lv_latvian_model.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'LICENSE'
# warning: no files found matching 'LICENSES_SOURCES'
# writing manifest file 'lv_latvian_model.egg-info/SOURCES.txt'
# * Building sdist...
# running sdist
# running egg_info
# writing lv_latvian_model.egg-info/PKG-INFO
# writing dependency_links to lv_latvian_model.egg-info/dependency_links.txt
# writing entry points to lv_latvian_model.egg-info/entry_points.txt
# writing requirements to lv_latvian_model.egg-info/requires.txt
# writing top-level names to lv_latvian_model.egg-info/top_level.txt
# reading manifest file 'lv_latvian_model.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'LICENSE'
# warning: no files found matching 'LICENSES_SOURCES'
# writing manifest file 'lv_latvian_model.egg-info/SOURCES.txt'
# running check
# creating lv_latvian_model-1.0.0
# creating lv_latvian_model-1.0.0/lv_latvian_model
# creating lv_latvian_model-1.0.0/lv_latvian_model.egg-info
# creating lv_latvian_model-1.0.0/lv_latvian_model/lv_latvian_model-1.0.0
# creating lv_latvian_model-1.0.0/lv_latvian_model/lv_latvian_model-1.0.0/lookups
# creating lv_latvian_model-1.0.0/lv_latvian_model/lv_latvian_model-1.0.0/morphologizer
# creating lv_latvian_model-1.0.0/lv_latvian_model/lv_latvian_model-1.0.0/parser
# creating lv_latvian_model-1.0.0/lv_latvian_model/lv_latvian_model-1.0.0/tagger
# creating lv_latvian_model-1.0.0/lv_latvian_model/lv_latvian_model-1.0.0/tok2vec
# creating lv_latvian_model-1.0.0/lv_latvian_model/lv_latvian_model-1.0.0/vocab
# copying files to lv_latvian_model-1.0.0...
# copying MANIFEST.in -> lv_latvian_model-1.0.0
# copying README.md -> lv_latvian_model-1.0.0
# copying meta.json -> lv_latvian_model-1.0.0
# copying setup.py -> lv_latvian_model-1.0.0
# copying lv_latvian_model/__init__.py -> lv_latvian_model-1.0.0/lv_latvian_model
# copying lv_latvian_model/meta.json -> lv_latvian_model-1.0.0/lv_latvian_model
# copying lv_latvian_model.egg-info/PKG-INFO -> lv_latvian_model-1.0.0/lv_latvian_model.egg-info
# copying lv_latvian_model.egg-info/SOURCES.txt -> lv_latvian_model-1.0.0/lv_latvian_model.egg-info
# copying lv_latvian_model.egg-info/dependency_links.txt -> lv_latvian_model-1.0.0/lv_latvian_model.egg-info
# copying lv_latvian_model.egg-info/entry_points.txt -> lv_latvian_model-1.0.0/lv_latvian_model.egg-info
# copying lv_latvian_model.egg-info/not-zip-safe -> lv_latvian_model-1.0.0/lv_latvian_model.egg-info
# copying lv_latvian_model.egg-info/requires.txt -> lv_latvian_model-1.0.0/lv_latvian_model.egg-info
# copying lv_latvian_model.egg-info/top_level.txt -> lv_latvian_model-1.0.0/lv_latvian_model.egg-info
# copying lv_latvian_model/lv_latvian_model-1.0.0/README.md -> lv_latvian_model-1.0.0/lv_latvian_model/lv_latvian_model-1.0.0
# copying lv_latvian_model/lv_latvian_model-1.0.0/config.cfg -> lv_latvian_model-1.0.0/lv_latvian_model/lv_latvian_model-1.0.0
# copying lv_latvian_model/lv_latvian_model-1.0.0/meta.json -> lv_latvian_model-1.0.0/lv_latvian_model/lv_latvian_model-1.0.0
# copying lv_latvian_model/lv_latvian_model-1.0.0/tokenizer -> lv_latvian_model-1.0.0/lv_latvian_model/lv_latvian_model-1.0.0
# copying lv_latvian_model/lv_latvian_model-1.0.0/lookups/lemma_lookup.json -> lv_latvian_model-1.0.0/lv_latvian_model/lv_latvian_model-1.0.0/lookups
# copying lv_latvian_model/lv_latvian_model-1.0.0/morphologizer/cfg -> lv_latvian_model-1.0.0/lv_latvian_model/lv_latvian_model-1.0.0/morphologizer
# copying lv_latvian_model/lv_latvian_model-1.0.0/morphologizer/model -> lv_latvian_model-1.0.0/lv_latvian_model/lv_latvian_model-1.0.0/morphologizer
# copying lv_latvian_model/lv_latvian_model-1.0.0/parser/cfg -> lv_latvian_model-1.0.0/lv_latvian_model/lv_latvian_model-1.0.0/parser
# copying lv_latvian_model/lv_latvian_model-1.0.0/parser/model -> lv_latvian_model-1.0.0/lv_latvian_model/lv_latvian_model-1.0.0/parser
# copying lv_latvian_model/lv_latvian_model-1.0.0/parser/moves -> lv_latvian_model-1.0.0/lv_latvian_model/lv_latvian_model-1.0.0/parser
# copying lv_latvian_model/lv_latvian_model-1.0.0/tagger/cfg -> lv_latvian_model-1.0.0/lv_latvian_model/lv_latvian_model-1.0.0/tagger
# copying lv_latvian_model/lv_latvian_model-1.0.0/tagger/model -> lv_latvian_model-1.0.0/lv_latvian_model/lv_latvian_model-1.0.0/tagger
# copying lv_latvian_model/lv_latvian_model-1.0.0/tok2vec/cfg -> lv_latvian_model-1.0.0/lv_latvian_model/lv_latvian_model-1.0.0/tok2vec
# copying lv_latvian_model/lv_latvian_model-1.0.0/tok2vec/model -> lv_latvian_model-1.0.0/lv_latvian_model/lv_latvian_model-1.0.0/tok2vec
# copying lv_latvian_model/lv_latvian_model-1.0.0/vocab/key2row -> lv_latvian_model-1.0.0/lv_latvian_model/lv_latvian_model-1.0.0/vocab
# copying lv_latvian_model/lv_latvian_model-1.0.0/vocab/lookups.bin -> lv_latvian_model-1.0.0/lv_latvian_model/lv_latvian_model-1.0.0/vocab
# copying lv_latvian_model/lv_latvian_model-1.0.0/vocab/strings.json -> lv_latvian_model-1.0.0/lv_latvian_model/lv_latvian_model-1.0.0/vocab
# copying lv_latvian_model/lv_latvian_model-1.0.0/vocab/vectors -> lv_latvian_model-1.0.0/lv_latvian_model/lv_latvian_model-1.0.0/vocab
# copying lv_latvian_model/lv_latvian_model-1.0.0/vocab/vectors.cfg -> lv_latvian_model-1.0.0/lv_latvian_model/lv_latvian_model-1.0.0/vocab
# copying lv_latvian_model.egg-info/SOURCES.txt -> lv_latvian_model-1.0.0/lv_latvian_model.egg-info
# Writing lv_latvian_model-1.0.0/setup.cfg
# Creating tar archive
# removing 'lv_latvian_model-1.0.0' (and everything under it)
# Successfully built lv_latvian_model-1.0.0.tar.gz
# ✔ Successfully created zipped Python package
# packages/lv_latvian_model-1.0.0/dist/lv_latvian_model-1.0.0.tar.gz

# %%
# Cell 9: 安装并测试打包好的拉脱维亚语模型
import subprocess
import spacy

# 安装打包好的模型
package_path = "./packages/lv_latvian_model-1.0.0/dist/lv_latvian_model-1.0.0.tar.gz"

# 使用 subprocess 调用 pip 安装（Notebook 内直接运行也可以）
subprocess.run(["pip", "install", package_path])
# Out:
# Processing ./packages/lv_latvian_model-1.0.0/dist/lv_latvian_model-1.0.0.tar.gz
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: spacy<3.9.0,>=3.8.7 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from lv_latvian_model==1.0.0) (3.8.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (0.16.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (2.3.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (2.11.7)
# Requirement already satisfied: jinja2 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (3.1.6)
# Requirement already satisfied: setuptools in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (2025.8.3)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from thinc<8.4.0,>=8.3.4->spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from thinc<8.4.0,>=8.3.4->spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (14.1.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (0.21.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (7.3.0.post1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from jinja2->spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (1.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (2.19.2)
# Requirement already satisfied: wrapt in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (1.17.3)
# Requirement already satisfied: mdurl~=0.1 in /home/jesse/Projects/myenvs/spacy_lv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.9.0,>=3.8.7->lv_latvian_model==1.0.0) (0.1.2)
# Building wheels for collected packages: lv_latvian_model
#   Building wheel for lv_latvian_model (pyproject.toml): started
#   Building wheel for lv_latvian_model (pyproject.toml): finished with status 'done'
#   Created wheel for lv_latvian_model: filename=lv_latvian_model-1.0.0-py3-none-any.whl size=9049687 sha256=a0a1052f2727ac346c3e7e71e3d3f442223bc9aad7b95dc1b477f34e6fcfe5f4
#   Stored in directory: /home/jesse/.cache/pip/wheels/7a/9e/71/1e57930844b68e7ad0ecd8336bccc8e0cf32783841865bc649
# Successfully built lv_latvian_model
# Installing collected packages: lv_latvian_model
#   Attempting uninstall: lv_latvian_model
#     Found existing installation: lv_latvian_model 1.0.0
#     Uninstalling lv_latvian_model-1.0.0:
#       Successfully uninstalled lv_latvian_model-1.0.0
# Successfully installed lv_latvian_model-1.0.0
# CompletedProcess(args=['pip', 'install', './packages/lv_latvian_model-1.0.0/dist/lv_latvian_model-1.0.0.tar.gz'], returncode=0)

# %%
# 加载模型
# 安装后，包名是 lv_latvian_model
nlp = spacy.load("lv_latvian_model")

# 测试文本
# 你可以用 wiki 或者任何拉脱维亚语文本，这里举个示例
text = """
Rīga ir Latvijas galvaspilsēta un viens no galvenajiem rūpniecības, darījumu, kultūras, sporta un finanšu centriem Baltijas valstīs, kā arī nozīmīga ostas pilsēta. Ar 605 273 iedzīvotājiem (2024. gada dati) tā ir lielākā apdzīvotā vieta Latvijā. Tās robežās dzīvo aptuveni viena trešdaļa, bet Rīgas aglomerācijā — vairāk nekā puse visu Latvijas iedzīvotāju. Pilsētas teritorijas platība ir 307,17 km2. Rīgas vēsturiskais centrs ir iekļauts UNESCO Pasaules kultūras mantojuma sarakstā un ir ievērojams ar jūgendstila arhitektūru, kurai, pēc UNESCO viedokļa, nav līdzīgu pasaulē.
"""

doc = nlp(text)

# 输出分析结果
print("TOKEN\tLEMMA\tPOS\tTAG\tDEP\tHEAD")
for token in doc:
    print(f"{token.text}\t{token.lemma_}\t{token.pos_}\t{token.tag_}\t{token.dep_}\t{token.head.text}")

# 句子划分
print("\n句子划分:")
for sent in doc.sents:
    print(sent.text)
# Out:
# TOKEN	LEMMA	POS	TAG	DEP	HEAD
#
# 		NOUN	ncmsd2	nmod	Rīga
# Rīga		PROPN	npfsn4	nsubj	galvaspilsēta
# ir		AUX	vcnipii30an	cop	galvaspilsēta
# Latvijas		PROPN	npfsg4	nmod	galvaspilsēta
# galvaspilsēta		NOUN	ncfsn4	ROOT	galvaspilsēta
# un		CCONJ	cc	cc	viens
# viens		NUM	mcsmsn	conj	galvaspilsēta
# no		ADP	sppd	case	centriem
# galvenajiem		ADJ	armpdyp	amod	centriem
# rūpniecības		NOUN	ncfsg4	nmod	centriem
# ,		PUNCT	zc	punct	darījumu
# darījumu		NOUN	ncmpg1	conj	rūpniecības
# ,		PUNCT	zc	punct	kultūras
# kultūras		NOUN	ncfsg4	conj	rūpniecības
# ,		PUNCT	zc	punct	sporta
# sporta		NOUN	ncmsg1	conj	rūpniecības
# un		CCONJ	cc	cc	finanšu
# finanšu		NOUN	ncfdg5	conj	rūpniecības
# centriem		NOUN	ncmpd1	nmod	viens
# Baltijas		PROPN	npfsg4	nmod	valstīs
# valstīs		NOUN	ncfpl6	nmod	centriem
# ,		PUNCT	zc	punct	pilsēta
# kā		PART	q	cc	pilsēta
# arī		CCONJ	cc	fixed	kā
# nozīmīga		ADJ	afmsgnp	amod	pilsēta
# ostas		NOUN	ncfsg4	nmod	pilsēta
# pilsēta		NOUN	ncfsn4	conj	galvaspilsēta
# .		PUNCT	zs	punct	iedzīvotājiem
# Ar		ADP	sppd	case	iedzīvotājiem
# 605		NUM	xn	nummod	iedzīvotājiem
# 273		NUM	xn	nummod	iedzīvotājiem
# iedzīvotājiem		NOUN	ncmpd1	nmod	pilsēta
# (		PUNCT	zb	punct	dati
# 2024		ADJ	xo	amod	gada
# .		ADJ	xo	amod	gada
# gada		NOUN	ncmsg1	nmod	dati
# dati		NOUN	ncmdn1	parataxis	pilsēta
# )		PUNCT	zb	punct	dati
# tā		DET	pd3fsnn	advmod	vieta
# ir		AUX	vcnipii30an	cop	vieta
# lielākā		ADJ	affsnyc	amod	vieta
# apdzīvotā		VERB	vmnpdfsnpsypn	amod	vieta
# vieta		NOUN	ncfsn4	conj	galvaspilsēta
# Latvijā		PROPN	npfsl4	nmod	vieta
# .		PUNCT	zs	punct	dzīvo
# Tās		DET	pd3fsgn	det	robežās
# robežās		NOUN	ncfpl4	obl	dzīvo
# dzīvo		VERB	vmnipt230an	conj	galvaspilsēta
# aptuveni		ADV	rpn	advmod	viena
# viena		NUM	mcsfsn	nummod	trešdaļa
# trešdaļa		NOUN	ncfsn4	nsubj	dzīvo
# ,		PUNCT	zc	punct	km2
# bet		CCONJ	cc	cc	km2
# Rīgas		PROPN	npfsg4	nmod	aglomerācijā
# aglomerācijā		NOUN	ncfsl4	orphan	km2
# —		PUNCT	zd	punct	km2
# vairāk		ADV	rcn	acl	puse
# nekā		SCONJ	cs	fixed	vairāk
# puse		NOUN	ncfsn5	nsubj	km2
# visu		DET	pg0msan	det	iedzīvotāju
# Latvijas		PROPN	npfsg4	nmod	iedzīvotāju
# iedzīvotāju		NOUN	ncmpg1	nmod	puse
# .		PUNCT	xo	nmod	puse
# Pilsētas		NOUN	ncfsg4	nmod	teritorijas
# teritorijas		NOUN	ncfsg4	nmod	platība
# platība		NOUN	ncfsn4	conj	puse
# ir		AUX	vcnipii30an	cop	km2
# 307,17		NUM	xn	nummod	km2
# km2		NOUN	ncmpl1	conj	galvaspilsēta
# .		PUNCT	zs	punct	galvaspilsēta
# Rīgas		PROPN	npfsg4	nmod	centrs
# vēsturiskais		ADJ	afmsnyp	amod	centrs
# centrs		NOUN	ncmsn1	nsubj:pass	iekļauts
# ir		AUX	vcnipii30an	aux:pass	iekļauts
# iekļauts		VERB	vmnpdmsnpsnpn	conj	galvaspilsēta
# UNESCO		PROPN	yp	nmod	mantojuma
# Pasaules		NOUN	ncfsg5	nmod	kultūras
# kultūras		NOUN	ncfsg4	nmod	mantojuma
# mantojuma		NOUN	ncmsg1	nmod	sarakstā
# sarakstā		NOUN	ncmsl1	obl	iekļauts
# un		CCONJ	cc	cc	ievērojams
# ir		AUX	vcnipii30an	cop	ievērojams
# ievērojams		VERB	vmnpdmsnppnpn	conj	iekļauts
# ar		ADP	spsa	case	arhitektūru
# jūgendstila		NOUN	ncmsg1	nmod	arhitektūru
# arhitektūru		NOUN	ncfsa4	iobj	ievērojams
# ,		PUNCT	zc	punct	nav
# kurai		DET	pr0fsdn	obl	nav
# ,		PUNCT	zc	punct	viedokļa
# pēc		ADP	spsg	case	viedokļa
# UNESCO		PROPN	yp	nmod	viedokļa
# viedokļa		NOUN	ncmsg2	acl	kurai
# ,		PUNCT	zc	punct	viedokļa
# nav		VERB	vmnipii30ay	acl	arhitektūru
# līdzīgu		ADJ	affpgnp	amod	pasaulē
# pasaulē		NOUN	ncfsl5	obl	nav
# .		PUNCT	zs	punct	iekļauts
#
# 		NOUN	vmnipt130an	conj	galvaspilsēta
#
# 句子划分:
#
# Rīga ir Latvijas galvaspilsēta un viens no galvenajiem rūpniecības, darījumu, kultūras, sporta un finanšu centriem Baltijas valstīs, kā arī nozīmīga ostas pilsēta. Ar 605 273 iedzīvotājiem (2024. gada dati) tā ir lielākā apdzīvotā vieta Latvijā. Tās robežās dzīvo aptuveni viena trešdaļa, bet Rīgas aglomerācijā — vairāk nekā puse visu Latvijas iedzīvotāju. Pilsētas teritorijas platība ir 307,17 km2. Rīgas vēsturiskais centrs ir iekļauts UNESCO Pasaules kultūras mantojuma sarakstā un ir ievērojams ar jūgendstila arhitektūru, kurai, pēc UNESCO viedokļa, nav līdzīgu pasaulē.
